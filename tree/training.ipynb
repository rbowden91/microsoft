# %%
# %run model.py --model=small --data_path=../data/tree7 --save_path=../data/tree7/full
# Out:
# INFO:tensorflow:Summary name Training Loss is illegal; using Training_Loss instead.
# INFO:tensorflow:Summary name Learning Rate is illegal; using Learning_Rate instead.
# INFO:tensorflow:Summary name Validation Loss is illegal; using Validation_Loss instead.
# Epoch: 1 Learning rate: 1.000
# 1922.9
# 1115.71
# 2453.1
# 1261.04
# 914.823
# 1261.79
# 876.517
# 1276.21
# 1225.03
# 2373.75
# 1347.5
# 965.665
# 1190.54
# 903.805
# 1167.24
# 1330.12
# 2637.49
# 1929.31
# 1165.7
# 1114.74
# 1301.7
# 953.103
# 1519.27
# 1214.51
# 747.861
# 1561.02
# 544.921
# 1457.24
# 626.71
# 1243.6
# 564.613
# 1186.13
# 565.536
# 695.767
# 694.565
# 815.562
# 1143.97
# 542.951
# 1087.51
# 951.575
# 778.584
# 673.083
# 644.901
# 1403.48
# 616.476
# 725.746
# 449.371
# 562.811
# 1344.07
# 1177.47
# 741.563
# 733.302
# 1007.38
# 578.012
# 1499.99
# 388.486
# 1904.78
# 674.614
# 385.385
# 893.527
# 1296.94
# 606.89
# 1007.8
# 742.625
# 408.463
# 438.223
# 580.738
# 611.529
# 612.533
# 413.55
# 1262.21
# ...

# %%
# %run server.py --data_path=../data/tree7 --save_path=../data/tree7/full --task_path=../tasks
# Out:
# INFO:tensorflow:Restoring parameters from ../data/tree7/full\tree_model
